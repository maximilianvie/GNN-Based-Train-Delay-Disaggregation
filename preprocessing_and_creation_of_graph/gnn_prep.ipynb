# %%
import torch
import pandas as pd
import networkx as nx
from torch_geometric.data import Data
import numpy as np
import networkx as nx
import pickle
import os
import glob
from statistics import mode
import matplotlib.pyplot as plt

# %%
def preprocess_data(file_path, nrows):

    # Load the data from the file
    data = pd.read_csv(file_path, sep=',', nrows=nrows)

    data['arrival'] = pd.to_datetime(data['arrival'], errors='coerce')
    data['departure'] = pd.to_datetime(data['departure'], errors='coerce')

    data.rename(columns={'latitude': 'temp_latitude', 'longitude': 'latitude'}, inplace=True)
    data.rename(columns={'temp_latitude': 'longitude'}, inplace=True)

    return data

# %%
def create_graph_from_data(data, seconds_since_last_train, file_number = None):
    # Sort and filter data first
    filtered_data = data.sort_values(by=['train_number', 'train_unique_sequence'])

    # Create the graph
    G = nx.DiGraph()

    # Phase 1: Node Creation
    # Using both 'train_number' and 'train_unique_sequence' for a unique index
    filtered_data['node_id'] = filtered_data.apply(
        lambda row: f"{row['train_number']}_{row['train_unique_sequence']}", axis=1
    )

    # Select only specific columns for node attributes
    selected_attributes = ['train_number',
                           'train_unique_sequence',
                           'ocp_type', 
                           'freight',
                           'number_of_traction_units', 
                           'departure_delay_seconds',  
                           'arrival_delay_seconds', 
                           'longitude', 
                           'latitude', 
                           'sin_seconds_since_midnight_departure',
                           'cos_seconds_since_midnight_departure',
                           'sin_seconds_since_midnight_arrival',
                           'cos_seconds_since_midnight_arrival',
                           'day_value',
                           'trainpart_weight',
                           'primary_delay',
                           'operator_class', 
                           'category',
                           'primary_delay_label',
                           'nodes_to_classify',
                           'delay_jump'
                           ]
    

    
    node_attributes = filtered_data.set_index('node_id')[selected_attributes].to_dict('index')

    # Add 'is_supernode' attribute for regular nodes
    for node_id, attrs in node_attributes.items():
        attrs['file_number'] = file_number
        attrs['is_supernode'] = 0
    G.add_nodes_from(node_attributes.items())


    # Phase 2: Edge Creation
    for train_number, group in filtered_data.groupby('train_number'):
        node_ids = group['node_id'].tolist()
        #print(f"Train {train_number}: Node IDs: {node_ids}")
        for i in range(len(node_ids) - 1):

            if not G.has_edge(node_ids[i], node_ids[i + 1]):
                G.add_edge(node_ids[i], node_ids[i + 1])
            if not G.has_edge(node_ids[i + 1], node_ids[i]):
                G.add_edge(node_ids[i + 1], node_ids[i])

    # Phase 3: Create supernodes and connect them
    train_numbers = filtered_data['train_number'].unique()
    for train_number in train_numbers:
        supernode_id = f"supernode_{train_number}"

        # Get the train nodes with the same train number as the supernode
        train_nodes = filtered_data[filtered_data['train_number'] == train_number]
        
        # Calculate the maximum values for each attribute from the train nodes
        supernode_attributes = {}
        for attr in selected_attributes:
            if attr == 'train_number':
                supernode_attributes[attr] = train_number
            else:
                attr_values = train_nodes[attr].tolist()
                attr_values = [val for val in attr_values if val is not None]
                
                if attr_values:
                    if pd.api.types.is_numeric_dtype(attr_values):
                        supernode_attributes[attr] = max(attr_values)
                    elif attr in ['ocp_type', 'operator_class', 'category']:  # Categorical attributes
                        supernode_attributes[attr] = mode(attr_values)
                    else:
                        supernode_attributes[attr] = max(attr_values, key=lambda x: (isinstance(x, str), x))
                else:
                    supernode_attributes[attr] = np.nan
        
        supernode_attributes['file_number'] = file_number
        supernode_attributes['is_supernode'] = 1
        
        G.add_node(supernode_id, **supernode_attributes)
        
        train_nodes = filtered_data[filtered_data['train_number'] == train_number]['node_id']
        for node in train_nodes:
            if not G.has_edge(supernode_id, node):
                G.add_edge(supernode_id, node)  # Supernode to regular node
            if not G.has_edge(node, supernode_id):
                G.add_edge(node, supernode_id)


    # Phase 4: Adding edges between recently used stations
    recent_trains_at_station = {}
    supernode_connections = set()

    
    # Preprocess the data for time calculations
    data['time'] = pd.to_datetime(data['arrival']).fillna(pd.to_datetime(data['departure']))
    data['node_id'] = data.apply(lambda row: f"{row['train_number']}_{row['train_unique_sequence']}", axis=1)

    # Ensure the data is sorted by time
    data.sort_values(by='time', inplace=True)

    for db640_code, group in data.groupby('db640_code'):
        for i, row in group.iterrows():
            

            current_time = row['time']
            event_node = row['node_id']

            if db640_code in recent_trains_at_station:
                for train_time, train_number in recent_trains_at_station[db640_code]:
                    time_difference = abs((current_time - train_time).total_seconds())
                    
                    if time_difference <= seconds_since_last_train and train_number != row['train_number']:
                      
                        last_train_node = f"{train_number}_{group.loc[(group['db640_code'] == db640_code) & (group['train_number'] == train_number) & (group['time'] == train_time), 'train_unique_sequence'].iloc[0]}"
                     
                        if G.has_node(last_train_node) and G.has_node(event_node):
                          
                            if not G.has_edge(last_train_node, event_node):
                                G.add_edge(last_train_node, event_node)
                            if not G.has_edge(event_node, last_train_node):
                                G.add_edge(event_node, last_train_node)
                          
                        
                            # Track connection between supernodes
                            last_train_supernode = f"supernode_{train_number}"
                            event_train_supernode = f"supernode_{row['train_number']}"
                            supernode_connections.add((last_train_supernode, event_train_supernode))

     
            
            # Update recent trains list
            if db640_code not in recent_trains_at_station:
                recent_trains_at_station[db640_code] = []
            recent_trains_at_station[db640_code].append((current_time, row['train_number']))


    # Phase 5: Add Directed Edges Between Supernodes based on tracked connections
    for supernode1, supernode2 in supernode_connections:
        if G.has_node(supernode1) and G.has_node(supernode2):

            if not G.has_edge(supernode1, supernode2):
                G.add_edge(supernode1, supernode2)
            if not G.has_edge(supernode2, supernode1):
                G.add_edge(supernode2, supernode1)


    print("Information about graph:")
    print(f"Number of nodes: {G.number_of_nodes()}")
    print(f"Number of edges: {G.number_of_edges()}")
    print(f"Is the graph directed: {G.is_directed()}")




    ############# This code can be uncommented to plot some graphs for testing
    """
    # Plot all nodes for testing
    # Find all subgraphs (connected components) in the graph
    subgraphs = [G.subgraph(c) for c in nx.strongly_connected_components(G)]

    # Filter subgraphs based on the number of nodes
    filtered_subgraphs = [subgraph for subgraph in subgraphs if 30 <= subgraph.number_of_nodes() <= 1000]

    # Print information about each filtered subgraph
    for i, subgraph in enumerate(filtered_subgraphs):
        print(f"Subgraph {i + 1}:")
        print(f"  Number of nodes: {subgraph.number_of_nodes()}")
        print(f"  Number of edges: {subgraph.number_of_edges()}")
        
        # Plot the subgraph
        pos = nx.spring_layout(subgraph, seed=42)  # Use a fixed seed for reproducibility
        
        # Create a new figure with a larger size
        fig, ax = plt.subplots(figsize=(20, 20))
        
        # Draw nodes with smaller size
        nx.draw_networkx_nodes(subgraph, pos, node_size=300, ax=ax)
        
        # Draw edges with arrows
        nx.draw_networkx_edges(subgraph, pos, arrows=True, arrowsize=20, ax=ax)
        
        # Draw node labels
        node_labels = {node: str(node) for node in subgraph.nodes()}
        nx.draw_networkx_labels(subgraph, pos, labels=node_labels, font_size=12, font_weight='bold', ax=ax)
        
        # Draw node ID labels
        node_id_labels = nx.get_node_attributes(subgraph, 'node_id')
        node_id_pos = {node: (x, y - 0.05) for node, (x, y) in pos.items()}  # Adjust the position of node ID labels
        nx.draw_networkx_labels(subgraph, node_id_pos, labels=node_id_labels, font_size=10, font_color='red', ax=ax)
        
        # Remove axis
        ax.axis('off')
        
        # Create the 'plots' folder if it doesn't exist
        if not os.path.exists('plots'):
            os.makedirs('plots')
        
        # Save the subgraph plot to the 'plots' folder
        plt.tight_layout()
        plt.savefig(f'plots/subgraph_{file_number}_{i + 1}.png', dpi=300)
        plt.close(fig)  # Close the figure to free up memory

    # Print the number of filtered subgraphs
    print(f"Number of subgraphs with 30 to 1000 nodes: {len(filtered_subgraphs)}")

    """  

    return G

# %%
def extract_node_features_and_labels(G):
    x_list = []
    y_list = []

    nodes_to_train_on_count = 0
    nodes_not_to_train_on_count = 0

    train_label_one_count = 0
    train_label_zero_count = 0

    for node in G.nodes:

        # Example node attribute extraction
        node_attributes = G.nodes[node]

        # Extract input features
        train_number = node_attributes['train_number']
        train_unique_sequence = node_attributes['train_unique_sequence']
        ocp_type = node_attributes['ocp_type']
        freight = node_attributes['freight']
        number_of_traction_units = node_attributes['number_of_traction_units']
        departure_delay_seconds = node_attributes['departure_delay_seconds']
        arrival_delay_seconds = node_attributes['arrival_delay_seconds']
        longitude = node_attributes['longitude']
        latitude = node_attributes['latitude']
        sin_departure = node_attributes['sin_seconds_since_midnight_departure']
        cos_departure = node_attributes['cos_seconds_since_midnight_departure']
        sin_arrival = node_attributes['sin_seconds_since_midnight_arrival']
        cos_arrival = node_attributes['cos_seconds_since_midnight_arrival']
        day_value = node_attributes['day_value']
        trainpart_weight = node_attributes['trainpart_weight']
        operator_class = node_attributes['operator_class']
        category = node_attributes['category']
        primary_delay_label = node_attributes['primary_delay_label']
        primary_delay = node_attributes['primary_delay']
        delay_change = node_attributes['delay_jump']

        nodes_to_classify = node_attributes['nodes_to_classify']
        file_number = node_attributes['file_number']
        is_supernode = node_attributes['is_supernode']

        # Encode binary and categorical features
        encoded_nodes_to_classify = 1 if nodes_to_classify else 0
        encoded_primary_delay_label = 1 if primary_delay_label else 0
        encoded_ocp_type = 1 if ocp_type == 'Stop' else 0
        encoded_freight = 1 if freight else 0

        # We only want to train on nodes that are not supernodes
        nodes_to_train_on = encoded_nodes_to_classify and not is_supernode

        if nodes_to_train_on:
            nodes_to_train_on_count += 1
            if encoded_primary_delay_label == 1:
                train_label_one_count += 1
            else:
                train_label_zero_count += 1
        else:
            nodes_not_to_train_on_count += 1


        # Append input features to the list
        x_list.append([
            category, operator_class, longitude, latitude, trainpart_weight,
            departure_delay_seconds, arrival_delay_seconds, delay_change, train_unique_sequence,
            number_of_traction_units, sin_departure, cos_departure,
            sin_arrival, cos_arrival, day_value, encoded_freight, 
            encoded_ocp_type, nodes_to_train_on, 
            train_number, file_number, is_supernode
        ])

        y_list.append((encoded_primary_delay_label, float(primary_delay)))


    x = torch.tensor(x_list, dtype=torch.float)
    y = torch.tensor(y_list, dtype=torch.float)


    # Check for NaN values
    if np.isnan(x.numpy()).any() or np.isnan(y.numpy()).any():
        raise ValueError("NaN values detected in x or y tensors.")
    
    print(f"Nodes to train on: {nodes_to_train_on_count}")
    print(f"Nodes not to train on: {nodes_not_to_train_on_count}")
    print(f"Nodes to train on with label 1: {train_label_one_count}")
    print(f"Nodes to train on with label 0: {train_label_zero_count}")


    return x, y

# %%
def create_pyg_data_object(G, x, y):
    node_to_int = {node: i for i, node in enumerate(G.nodes)}
    edges_as_int = [(node_to_int[src], node_to_int[dst]) for src, dst in G.edges]
    edge_index = torch.tensor(edges_as_int).t().contiguous()

    data = Data(x=x, edge_index=edge_index, y=y)
    return data

# %%
def process_graph(G, min_nodes, set_assignment):
    undirected_G = G.to_undirected()
    components = list(nx.connected_components(undirected_G))
    data_objects = []
    max_nodes = 0

    for j, component in enumerate(components):
        component_size = len(component)
        if component_size > min_nodes:
            subgraph = G.subgraph(component)
            print(f"Information about SUBGRAPH: {j}")
            print(f"Number of nodes: {subgraph.number_of_nodes()}")
            print(f"Number of edges: {subgraph.number_of_edges()}")
            print(f"Is the graph directed: {subgraph.is_directed()}")


            max_nodes = max(max_nodes, subgraph.number_of_nodes())
            x, y = extract_node_features_and_labels(subgraph)
            pyg_data_object = create_pyg_data_object(subgraph, x, y)

            pyg_data_object.set_type = set_assignment 

            data_objects.append(pyg_data_object)

    print(f"Largest graph size: {max_nodes}")
    return data_objects

# %%
def process_files(file_paths, nrows, min_nodes, seconds_since_last_train, output_file_path):
    all_data_objects = []
    i = 0
    num_files = len(file_paths)

    # Adjusting for equal distribution of augmentation methods in the train set
    num_train_files = int(0.8 * num_files)  # 80% of files are for training
    #augmentation_split = num_train_files // 2 # Divide train files equally among the 3 methods

    num_test_files = int(0.10 * num_files) + num_train_files  # Next 10% after train files
    # Remaining files are for validation


    for file_path in file_paths:
        data = preprocess_data(file_path, nrows)
        i += 1

        file_type = 0 if i <= num_train_files else (1 if i <= num_test_files else 2)

        print("We now have a file of type:")
        print(file_type)

        # Keep track of the processing method
        print(f"Processing file {i}")

        # Adjusting processing based on file index
        if i <= num_files:  

            print(f"Processing file {i}")
            G = create_graph_from_data(data, seconds_since_last_train=seconds_since_last_train, file_number=i)
            all_data_objects.extend(process_graph(G, min_nodes, file_type))


    with open(output_file_path, 'wb') as file:
        pickle.dump(all_data_objects, file)

   
    return all_data_objects

# %%
# Specify the directory where the CSV files are located
data_directory = 'data'  # Replace with your directory path

# List all CSV files in the directory
file_paths = glob.glob(os.path.join(data_directory, '*.csv'))
nrows = None  # Set to None to read all rows or specify a number to read a subset
min_nodes = 1000 # Minimum number of nodes in a subgraph to be considered
seconds_since_last_train = 180
output_file_path = 'dataset.pkl'

all_data_objects = process_files(file_paths, nrows, min_nodes, seconds_since_last_train, output_file_path)
# Out:
# We now have a file of type:
# 2
# Processing file 1
# Processing file 1
# Information about graph:
# Number of nodes: 289123
# Number of edges: 1387728
# Is the graph directed: True
# Information about SUBGRAPH: 0
# Number of nodes: 280064
# Number of edges: 1354700
# Is the graph directed: True
# Nodes to train on: 8795
# Nodes not to train on: 271269
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 8795
# Information about SUBGRAPH: 1
# Number of nodes: 34
# Number of edges: 132
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 32
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 2
# Number of nodes: 23
# Number of edges: 86
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 22
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 3
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 4
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 5
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 6
# Number of nodes: 22
# Number of edges: 82
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 20
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 7
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 8
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 9
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 10
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 11
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 12
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 13
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 14
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 15
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 16
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 17
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 18
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 19
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 20
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 21
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 22
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 23
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 24
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 25
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 26
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 27
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 28
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 29
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 30
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 31
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 32
# Number of nodes: 7
# Number of edges: 22
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 33
# Number of nodes: 22
# Number of edges: 82
# Is the graph directed: True
# Nodes to train on: 4
# Nodes not to train on: 18
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 4
# Information about SUBGRAPH: 34
# Number of nodes: 38
# Number of edges: 146
# Is the graph directed: True
# Nodes to train on: 3
# Nodes not to train on: 35
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 3
# Information about SUBGRAPH: 35
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 36
# Number of nodes: 30
# Number of edges: 118
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 30
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 37
# Number of nodes: 166
# Number of edges: 686
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 166
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 38
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 14
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 39
# Number of nodes: 172
# Number of edges: 704
# Is the graph directed: True
# Nodes to train on: 3
# Nodes not to train on: 169
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 3
# Information about SUBGRAPH: 40
# Number of nodes: 30
# Number of edges: 118
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 30
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 41
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 42
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 43
# Number of nodes: 108
# Number of edges: 438
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 108
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 44
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 45
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 14
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 46
# Number of nodes: 144
# Number of edges: 588
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 144
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 47
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 48
# Number of nodes: 837
# Number of edges: 3540
# Is the graph directed: True
# Nodes to train on: 16
# Nodes not to train on: 821
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 16
# Information about SUBGRAPH: 49
# Number of nodes: 183
# Number of edges: 750
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 182
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 50
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 51
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 52
# Number of nodes: 35
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 34
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 53
# Number of nodes: 39
# Number of edges: 150
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 39
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 54
# Number of nodes: 84
# Number of edges: 332
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 84
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 55
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 56
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 57
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 58
# Number of nodes: 22
# Number of edges: 82
# Is the graph directed: True
# Nodes to train on: 4
# Nodes not to train on: 18
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 4
# Information about SUBGRAPH: 59
# Number of nodes: 12
# Number of edges: 42
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 12
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 60
# Number of nodes: 12
# Number of edges: 42
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 12
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 61
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 62
# Number of nodes: 12
# Number of edges: 42
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 12
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 63
# Number of nodes: 12
# Number of edges: 42
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 64
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 65
# Number of nodes: 36
# Number of edges: 138
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 36
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 66
# Number of nodes: 36
# Number of edges: 138
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 35
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 67
# Number of nodes: 33
# Number of edges: 126
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 33
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 68
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 69
# Number of nodes: 22
# Number of edges: 82
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 22
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 70
# Number of nodes: 22
# Number of edges: 82
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 22
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 71
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 72
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 73
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 74
# Number of nodes: 50
# Number of edges: 196
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 48
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 75
# Number of nodes: 35
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 33
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 76
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 2
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 77
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 78
# Number of nodes: 40
# Number of edges: 154
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 40
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 79
# Number of nodes: 109
# Number of edges: 438
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 109
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 80
# Number of nodes: 77
# Number of edges: 310
# Is the graph directed: True
# Nodes to train on: 5
# Nodes not to train on: 72
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 5
# Information about SUBGRAPH: 81
# Number of nodes: 35
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 35
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 82
# Number of nodes: 20
# Number of edges: 74
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 20
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 83
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 84
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 85
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 86
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 87
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 88
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 89
# Number of nodes: 27
# Number of edges: 102
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 27
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 90
# Number of nodes: 44
# Number of edges: 174
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 44
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 91
# Number of nodes: 44
# Number of edges: 174
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 44
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 92
# Number of nodes: 44
# Number of edges: 174
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 43
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 93
# Number of nodes: 44
# Number of edges: 172
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 44
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 94
# Number of nodes: 34
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 34
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 95
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 96
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 97
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 98
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 99
# Number of nodes: 7
# Number of edges: 22
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 100
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 101
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 102
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 103
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 104
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 105
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 106
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 107
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 108
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 109
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 110
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 111
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 112
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 113
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 114
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 115
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 116
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 117
# Number of nodes: 20
# Number of edges: 72
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 20
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 118
# Number of nodes: 29
# Number of edges: 110
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 29
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 119
# Number of nodes: 78
# Number of edges: 306
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 78
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 120
# Number of nodes: 97
# Number of edges: 384
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 95
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 121
# Number of nodes: 23
# Number of edges: 86
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 23
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 122
# Number of nodes: 24
# Number of edges: 90
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 24
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 123
# Number of nodes: 24
# Number of edges: 90
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 24
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 124
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 19
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 125
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 19
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 126
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 127
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 18
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 128
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 19
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 129
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 19
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 130
# Number of nodes: 19
# Number of edges: 70
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 19
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 131
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 132
# Number of nodes: 7
# Number of edges: 22
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 133
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 134
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 135
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 136
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 137
# Number of nodes: 21
# Number of edges: 78
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 20
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 138
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 139
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 140
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 141
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 142
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 143
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 144
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 2
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 145
# Number of nodes: 32
# Number of edges: 126
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 32
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 146
# Number of nodes: 32
# Number of edges: 126
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 32
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 147
# Number of nodes: 32
# Number of edges: 126
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 32
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 148
# Number of nodes: 32
# Number of edges: 126
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 32
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 149
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 150
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 151
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 152
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 16
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 153
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 154
# Number of nodes: 27
# Number of edges: 102
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 27
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 155
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 156
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 157
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 158
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 159
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 160
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 161
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 162
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 163
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 164
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 165
# Number of nodes: 29
# Number of edges: 110
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 29
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 166
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 167
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 168
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 169
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 170
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 171
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 172
# Number of nodes: 13
# Number of edges: 46
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 173
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 174
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 175
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 176
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 177
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 178
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 179
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 180
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 181
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 182
# Number of nodes: 22
# Number of edges: 88
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 22
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 183
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 184
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 185
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 186
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 187
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 188
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 189
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 190
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 191
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 192
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 193
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 194
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 195
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 196
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 197
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 198
# Number of nodes: 25
# Number of edges: 94
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 25
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 199
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 200
# Number of nodes: 35
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 4
# Nodes not to train on: 31
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 4
# Information about SUBGRAPH: 201
# Number of nodes: 25
# Number of edges: 94
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 24
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 202
# Number of nodes: 34
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 33
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 203
# Number of nodes: 34
# Number of edges: 134
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 34
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 204
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 205
# Number of nodes: 31
# Number of edges: 118
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 30
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 206
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 207
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 208
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 209
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 210
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 211
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 212
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 213
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 214
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 215
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 216
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 217
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 218
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 219
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 220
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 221
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 222
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 223
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# ...
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 527
# Number of nodes: 16
# Number of edges: 58
# Is the graph directed: True
# Nodes to train on: 3
# Nodes not to train on: 13
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 3
# Information about SUBGRAPH: 528
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 529
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 530
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 531
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 2
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 532
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 533
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 534
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 535
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 536
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 537
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 538
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 539
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 540
# Number of nodes: 18
# Number of edges: 66
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 18
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 541
# Number of nodes: 7
# Number of edges: 22
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 542
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 543
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 544
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 545
# Number of nodes: 17
# Number of edges: 62
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 17
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 546
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 547
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 548
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 549
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 550
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 551
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 552
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 553
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 554
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 555
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 556
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 557
# Number of nodes: 4
# Number of edges: 10
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 558
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 559
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 560
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 561
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 3
# Nodes not to train on: 7
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 3
# Information about SUBGRAPH: 562
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 563
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 564
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 15
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 565
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 566
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 567
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 568
# Number of nodes: 12
# Number of edges: 42
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 12
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 569
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 570
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 571
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 572
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 573
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 574
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 575
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 576
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 577
# Number of nodes: 3
# Number of edges: 6
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 578
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 579
# Number of nodes: 11
# Number of edges: 38
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 11
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 580
# Number of nodes: 20
# Number of edges: 74
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 18
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 581
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 582
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 583
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 584
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 585
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 586
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 587
# Number of nodes: 7
# Number of edges: 22
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 588
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 589
# Number of nodes: 14
# Number of edges: 50
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 14
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 590
# Number of nodes: 29
# Number of edges: 110
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 29
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 591
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 5
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 592
# Number of nodes: 10
# Number of edges: 34
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 10
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 593
# Number of nodes: 6
# Number of edges: 18
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 6
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 594
# Number of nodes: 9
# Number of edges: 30
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 9
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 595
# Number of nodes: 8
# Number of edges: 26
# Is the graph directed: True
# Nodes to train on: 0
# Nodes not to train on: 8
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 0
# Information about SUBGRAPH: 596
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 4
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Information about SUBGRAPH: 597
# Number of nodes: 5
# Number of edges: 14
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 3
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 598
# Number of nodes: 22
# Number of edges: 82
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 20
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 599
# Number of nodes: 21
# Number of edges: 78
# Is the graph directed: True
# Nodes to train on: 2
# Nodes not to train on: 19
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 2
# Information about SUBGRAPH: 600
# Number of nodes: 15
# Number of edges: 54
# Is the graph directed: True
# Nodes to train on: 1
# Nodes not to train on: 14
# Nodes to train on with label 1: 0
# Nodes to train on with label 0: 1
# Largest graph size: 280064
